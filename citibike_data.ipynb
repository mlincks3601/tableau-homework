# %%
import os
import pandas as pd

# %%
feb_df = pd.read_csv('Resources/feb_2019.csv')
feb_df
# Out:
#         tripduration starttime stoptime  start station id  \
# 0                320   01:47.4  07:07.6            3160.0
# 1                316   04:43.7  10:00.6             519.0
# 2                591   06:04.0  15:55.4            3171.0
# 3               2719   07:03.5  52:22.6             504.0
# 4                303   07:35.9  12:39.5             229.0
# ...              ...       ...      ...               ...
# 967282           291   33:26.4  38:17.9            3354.0
# 967283           437   57:45.3  05:02.5            3354.0
# 967284           173   11:41.2  14:34.3            3354.0
# 967285           244   54:51.1  58:55.3            3354.0
# 967286           387   38:42.2  45:09.5            3354.0
#
#                  start station name  start station latitude  \
# 0       Central Park West & W 76 St               40.778968
# 1             Pershing Square North               40.751873
# 2           Amsterdam Ave & W 82 St               40.785247
# ...

# %%
march_df = pd.read_csv('Resources/march_2019.csv')
march_df
# Out:
#         tripduration starttime stoptime  start station id  \
# 0                219   00:06.3  03:46.1            3494.0
# 1                143   00:28.0  02:51.7             438.0
# 2                296   01:14.0  06:10.7            3571.0
# 3                478   01:14.2  09:12.8             167.0
# 4                225   01:49.3  05:34.5            3458.0
# ...              ...       ...      ...               ...
# 943739           979   59:43.4  16:02.8            2002.0
# 943740           779   59:48.2  12:47.5             229.0
# 943741           699   59:48.6  11:28.6             494.0
# 943742           284   59:59.3  04:43.7            3660.0
# 943743           279   59:55.0  04:34.9             362.0
#
#                   start station name  start station latitude  \
# 0           E 115 St & Lexington Ave               40.797911
# 1                St Marks Pl & 1 Ave               40.727791
# 2            Bedford Ave & Bergen St               40.676368
# ...

# %%
may_df = pd.read_csv('Resources/may_2019.csv')
may_df
# Out:
#          tripduration starttime stoptime  start station id  \
# 0                  88   00:14.7  01:42.9              2006
# 1                 443   00:20.8  07:44.3               254
# 2                 662   00:31.0  11:33.3              3244
# 3                  86   00:30.9  01:57.0               526
# 4                 136   00:32.6  02:49.4               461
# ...               ...       ...      ...               ...
# 1048570          3433   22:01.9  19:15.5              3108
# 1048571           328   22:02.2  27:31.0              3263
# 1048572           465   22:01.7  29:47.2              3674
# 1048573           919   22:03.5  37:23.0               297
# 1048574           402   22:02.8  28:45.3              3107
#
#                start station name  start station latitude  \
# 0          Central Park S & 6 Ave               40.765909
# 1                 W 11 St & 6 Ave               40.735324
# 2          University Pl & E 8 St               40.731437
# ...

# %%
april_df = pd.read_csv('Resources/april_2019.csv')
april_df
# Out:
#          tripduration starttime stoptime  start station id  \
# 0                1463   00:16.1  24:39.4             319.0
# 1                 285   00:32.4  05:18.2             439.0
# 2                 686   00:47.8  12:14.3             526.0
# 3                 442   01:01.2  08:23.8            3474.0
# 4                2913   01:09.3  49:42.4             379.0
# ...               ...       ...      ...               ...
# 1048570           272   28:28.3  33:01.0             349.0
# 1048571           615   28:26.6  38:42.3             466.0
# 1048572          1084   28:23.3  46:27.3            3259.0
# 1048573           511   28:23.6  36:55.2             492.0
# 1048574           173   28:29.5  31:23.3             402.0
#
#               start station name  start station latitude  \
# 0           Fulton St & Broadway               40.711066
# 1                 E 4 St & 2 Ave               40.726281
# 2                E 33 St & 5 Ave               40.747659
# ...

# %%
combined_data = pd.concat((feb_df, march_df, april_df, may_df), axis=0)
combined_data
# Out:
#          tripduration starttime stoptime  start station id  \
# 0                 320   01:47.4  07:07.6            3160.0
# 1                 316   04:43.7  10:00.6             519.0
# 2                 591   06:04.0  15:55.4            3171.0
# 3                2719   07:03.5  52:22.6             504.0
# 4                 303   07:35.9  12:39.5             229.0
# ...               ...       ...      ...               ...
# 1048570          3433   22:01.9  19:15.5            3108.0
# 1048571           328   22:02.2  27:31.0            3263.0
# 1048572           465   22:01.7  29:47.2            3674.0
# 1048573           919   22:03.5  37:23.0             297.0
# 1048574           402   22:02.8  28:45.3            3107.0
#
#                   start station name  start station latitude  \
# 0        Central Park West & W 76 St               40.778968
# 1              Pershing Square North               40.751873
# 2            Amsterdam Ave & W 82 St               40.785247
# ...

# %%
combined_data.to_csv(r'C:\Users\mlinc\Desktop\combined_data_citibikes.csv', index=False)
